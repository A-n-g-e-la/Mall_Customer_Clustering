# %% [markdown]
# <a href="https://colab.research.google.com/github/A-n-g-e-la/AI-Coursework-2025/blob/main/Mall_Customer_Clustering_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

# %%
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-5a7ee314-685a-4637-a919-7e5edbab6d5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a7ee314-685a-4637-a919-7e5edbab6d5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Question 2
df.info()#Generates the general summary of the dataset i.e What does the dataset look like and what is in it?
df.isnull().sum()#Looks for all null values in the datset. Empty cells ae marked as True so it also generates a general sum of all missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.dropna(inplace=True)# This basically removes any empty cells
df.isnull().sum()# We run this again to make sure there are no more empty cells/NULL values in the dataset
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)
print("Loaded:", filename)
# Out:
#      <input type="file" id="files-52378188-82aa-4674-a9fd-7b4e173af31e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52378188-82aa-4674-a9fd-7b4e173af31e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Shows the average values in all the columns
df.describe()


import seaborn as sns #Basically inporting the seaborn resource to help with generating the graphs
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df)
#Plots dots that compare income vs spending
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
sns.countplot(x='Gender', data=df)
#Bar graph comparing the number of men and women
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.histplot(df['Age'], bins=10, kde=True)
#This histogram shows the age droups of the customers
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Insight 1: Age Group
#Most customers are between 25 and 40 years old.
#This means that the mall is most popular with the youth and young adults

# %%
#Insight 2: Income vs Spending
#People who earn medium incomes tend to spend more money.
#So, the middle-income group are the mall’s most active shoppers.

# %%
#Insight 3: Gender
#There are slightly more female customers than male ones.
#This could mean women visit or shop at the mall more often.
